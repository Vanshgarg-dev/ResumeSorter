# %%
# !pip install -U spacy
# !pip install spacy_transformers
# !pip install pymupdf
# Out:
# Requirement already satisfied: spacy in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (2.7.1)
# Requirement already satisfied: jinja2 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: colorama in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.1.1)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: spacy_transformers in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (1.3.5)
# Requirement already satisfied: spacy<4.1.0,>=3.5.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy_transformers) (3.7.4)
# Requirement already satisfied: transformers<4.37.0,>=3.4.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy_transformers) (4.36.2)
# Requirement already satisfied: torch>=1.8.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy_transformers) (2.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy_transformers) (2.4.8)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy_transformers) (0.9.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy_transformers) (1.26.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (1.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (2.7.1)
# Requirement already satisfied: jinja2 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (3.4.0)
# Requirement already satisfied: filelock in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from torch>=1.8.0->spacy_transformers) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from torch>=1.8.0->spacy_transformers) (4.11.0)
# Requirement already satisfied: sympy in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from torch>=1.8.0->spacy_transformers) (1.12)
# Requirement already satisfied: networkx in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from torch>=1.8.0->spacy_transformers) (3.3)
# Requirement already satisfied: fsspec in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from torch>=1.8.0->spacy_transformers) (2024.3.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from torch>=1.8.0->spacy_transformers) (2021.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from transformers<4.37.0,>=3.4.0->spacy_transformers) (0.23.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from transformers<4.37.0,>=3.4.0->spacy_transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from transformers<4.37.0,>=3.4.0->spacy_transformers) (2024.4.28)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from transformers<4.37.0,>=3.4.0->spacy_transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from transformers<4.37.0,>=3.4.0->spacy_transformers) (0.4.3)
# Requirement already satisfied: language-data>=1.2 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (1.2.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->spacy_transformers) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->spacy_transformers) (2021.12.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.1.0,>=3.5.0->spacy_transformers) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.1.0,>=3.5.0->spacy_transformers) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.1.0,>=3.5.0->spacy_transformers) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.1.0,>=3.5.0->spacy_transformers) (0.1.4)
# Requirement already satisfied: colorama in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from jinja2->spacy<4.1.0,>=3.5.0->spacy_transformers) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from sympy->torch>=1.8.0->spacy_transformers) (1.3.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (1.1.1)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pymupdf in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (1.24.2)
# Requirement already satisfied: PyMuPDFb==1.24.1 in c:\users\devas\downloads\resumesorter\.venv\lib\site-packages (from pymupdf) (1.24.1)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy
from spacy.tokens import DocBin
from tqdm import tqdm
import json
import sys,fitz

# %%
nlp = spacy.load('./output/model-best')
# Out:
# c:\Users\devas\Downloads\ResumeSorter\.venv\Lib\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'en_pipeline' (0.0.0) was trained with spaCy v3.5.0 and may not be 100% compatible with the current version (3.7.4). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# c:\Users\devas\Downloads\ResumeSorter\.venv\Lib\site-packages\spacy_transformers\layers\hf_shim.py:137: UserWarning: Error loading saved torch state_dict with strict=True, likely due to differences between 'transformers' versions. Attempting to load with strict=False as a fallback...
#
# If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current 'transformers' and 'spacy-transformers' versions. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
fname ='./test/Shreya Bhandari.pdf'
doc = fitz.open(fname)

# %%
text = " "
for page in doc:
  text = text + str(page.get_text())

# %%
doc = nlp(text)
for ent in doc.ents:
  print(ent.text," ->>>>>",ent.label_)
# Out:
# www.linkedin.com/in/shreya-
# bhandari-a0094816b  ->>>>> LINKEDIN LINK
# Writing  ->>>>> SKILLS
# Python  ->>>>> SKILLS
# Django  ->>>>> SKILLS
# Nepali  ->>>>> LANGUAGE
# English  ->>>>> LANGUAGE
# Hindi  ->>>>> LANGUAGE
# Shreya Bhandari  ->>>>> NAME
# Kathmandu  ->>>>> LOCATION
# Danson Solutions  ->>>>> COMPANIES WORKED AT
# Business Analyst  ->>>>> WORKED AS
# 4 months  ->>>>> YEARS OF EXPERIENCE
# Girls in Tech  ->>>>> COMPANIES WORKED AT
# Event Team Ambassador  ->>>>> WORKED AS
# 4 months  ->>>>> YEARS OF EXPERIENCE
# Support Squad Ambassador  ->>>>> WORKED AS
# 4 months  ->>>>> YEARS OF EXPERIENCE
# 6 months  ->>>>> YEARS OF EXPERIENCE
# DansonTraining  ->>>>> COMPANIES WORKED AT
# 1 year 2 months  ->>>>> YEARS OF EXPERIENCE
# Finnove Technologies  ->>>>> COMPANIES WORKED AT
# 6 months  ->>>>> YEARS OF EXPERIENCE
# Associate Software Engineer  ->>>>> WORKED AS
# 1 month  ->>>>> YEARS OF EXPERIENCE
# Python Developer  ->>>>> WORKED AS
# 6 months  ->>>>> YEARS OF EXPERIENCE
# Danson Solutions  ->>>>> COMPANIES WORKED AT
# Data Science Intern  ->>>>> WORKED AS
# 3 months  ->>>>> YEARS OF EXPERIENCE
# ChimpVine  ->>>>> COMPANIES WORKED AT
# Graphic Designer  ->>>>> WORKED AS
# 5 months  ->>>>> YEARS OF EXPERIENCE
# VertexReport  ->>>>> COMPANIES WORKED AT
# Content Writer  ->>>>> WORKED AS
# 1 year 1 month  ->>>>> YEARS OF EXPERIENCE
# Vedic Himalayan Adve  ->>>>> COMPANIES WORKED AT
# Content Writer  ->>>>> WORKED AS
# 2 years 10 months  ->>>>> YEARS OF EXPERIENCE
# College of Information Technology  ->>>>> COLLEGE NAME
# Bachelor of Engineering - BE, Software engineering  ->>>>> DEGREE

# %%
job_description = {}
input_skills = []
input_skill = ""

while input_skill.lower() != "enough":
    input_skill = input("Enter skills required: ")
    input_skills.append(input_skill)


input_skills.remove("enough") 

print("Skills required:",input_skills)
input_degrequired=""
input_degrequired = input("Enter degree required: ")
# Out:
# Skills required: []

# %%
input_loc = input("Enter location of company: ")
