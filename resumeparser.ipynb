# %%
# !pip install -U spacy
# !pip install spacy_transformers
# !pip install pymupdf

# %%
import spacy
from spacy.tokens import DocBin
from tqdm import tqdm
import json
import sys,fitz
import os

# %%
nlp = spacy.load('./output/model-best')

# %%
fname ='./test/Shreya Bhandari.pdf'
doc = fitz.open(fname)

# %%
text = " "
for page in doc:
  text = text + str(page.get_text())

# %%
doc = nlp(text)
for ent in doc.ents:
  print(ent.text," ->>>>>",ent.label_)

# %%
job_description = {}
input_skills = []
input_skill = ""

while input_skill.lower() != "enough":
    input_skill = input("Enter skills required: ")
    input_skills.append(input_skill)


input_skills.remove("enough") 

print("Skills required:",input_skills)
input_degrequired=""
input_degrequired = input("Enter degree required: ")

# %%
input_loc = input("Enter location of company: ")

# %%
input_experiences = []
input_experience = ""
while input_experience.lower() != "enough":

    input_experience = input("Enter skills required: ")
    input_experiences.append(input_experience)

# %%
def get_files_in_folder(folder_path):
    files = []
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        if os.path.isfile(file_path):
            files.append(file_path)
    return files
